# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\yashh\\OneDrive\\Desktop\\CS 4375\\MarathonData.csv')

# %%
df.head()
# Out:
#    id  Marathon           Name Category  km4week    sp4week CrossTraining  \
# 0   1  Prague17   Blair MORGAN      MAM    132.8  14.434783           NaN
# 1   2  Prague17  Robert Heczko      MAM     68.6  13.674419           NaN
# 2   3  Prague17  Michon Jerome      MAM     82.7  13.520436           NaN
# 3   4  Prague17  Daniel Or lek      M45    137.5  12.258544           NaN
# 4   5  Prague17   Luk ? Mr zek      MAM     84.6  13.945055           NaN
#
#   Wall21  MarathonTime CATEGORY
# 0   1.16          2.37        A
# 1   1.23          2.59        A
# 2   1.30          2.66        A
# 3   1.32          2.68        A
# 4   1.36          2.74        A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             87 non-null     int64
#  1   Marathon       87 non-null     object
#  2   Name           87 non-null     object
#  3   Category       81 non-null     object
#  4   km4week        87 non-null     float64
#  5   sp4week        87 non-null     float64
#  6   CrossTraining  13 non-null     object
#  7   Wall21         87 non-null     object
#  8   MarathonTime   87 non-null     float64
#  9   CATEGORY       87 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 6.9+ KB

# %%
df.describe()
# Out:
#               id     km4week       sp4week  MarathonTime
# count  87.000000   87.000000     87.000000     87.000000
# mean   44.000000   62.347126    139.840706      3.319080
# std    25.258662   26.956019   1191.427864      0.376923
# min     1.000000   17.900000      8.031414      2.370000
# 25%    22.500000   44.200000     11.498168      3.045000
# 50%    44.000000   58.800000     12.163424      3.320000
# 75%    65.500000   77.500000     12.854036      3.605000
# max    87.000000  137.500000  11125.000000      3.980000

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df['id']
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 82    83
# 83    84
# 84    85
# 85    86
# 86    87
# Name: id, Length: 87, dtype: int64

# %%
df['Name']
# Out:
# 0         Blair MORGAN
# 1        Robert Heczko
# 2        Michon Jerome
# 3        Daniel Or lek
# 4         Luk ? Mr zek
#             ...
# 82    Stefano Vegliani
# 83      Andrej Madliak
# 84          Yoi Ohsako
# 85          Simon Dunn
# 86         Pavel ?imek
# Name: Name, Length: 87, dtype: object

# %%
df['Category']
# Out:
# 0     MAM
# 1     MAM
# 2     MAM
# 3     M45
# 4     MAM
#      ...
# 82    M55
# 83    M40
# 84    M40
# 85    M45
# 86    M40
# Name: Category, Length: 87, dtype: object

# %%
df['km4week']
# Out:
# 0     132.8
# 1      68.6
# 2      82.7
# 3     137.5
# 4      84.6
#       ...
# 82     50.0
# 83     33.6
# 84     55.4
# 85     33.2
# 86     17.9
# Name: km4week, Length: 87, dtype: float64

# %%
df['sp4week']
# Out:
# 0     14.434783
# 1     13.674419
# 2     13.520436
# 3     12.258544
# 4     13.945055
#         ...
# 82    10.830325
# 83    10.130653
# 84    11.043189
# 85    11.066667
# 86    10.848485
# Name: sp4week, Length: 87, dtype: float64

# %%
df['CrossTraining']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#          ...
# 82            NaN
# 83    ciclista 3h
# 84            NaN
# 85            NaN
# 86    ciclista 5h
# Name: CrossTraining, Length: 87, dtype: object

# %%
df['MarathonTime']
# Out:
# 0     2.37
# 1     2.59
# 2     2.66
# 3     2.68
# 4     2.74
#       ...
# 82    3.93
# 83    3.93
# 84    3.94
# 85    3.95
# 86    3.98
# Name: MarathonTime, Length: 87, dtype: float64

# %%
df['MarathonTime'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 87 entries, 0 to 86
# Series name: MarathonTime
# Non-Null Count  Dtype
# --------------  -----
# 87 non-null     float64
# dtypes: float64(1)
# memory usage: 824.0 bytes

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('darkgrid')
sns.countplot(x='CrossTraining', hue = 'CATEGORY', data = df, palette = 'RdBu_r')
# Out:
# <AxesSubplot:xlabel='CrossTraining', ylabel='count'>

# %%
sns.boxplot(x='MarathonTime', y='km4week', data=df)
# Out:
# <AxesSubplot:xlabel='MarathonTime', ylabel='km4week'>

# %%
sns.boxplot(x='CrossTraining', y='km4week', data=df)
# Out:
# <AxesSubplot:xlabel='CrossTraining', ylabel='km4week'>

# %%
sns.boxplot(x='km4week', y='MarathonTime', data=df)
# Out:
# <AxesSubplot:xlabel='km4week', ylabel='MarathonTime'>

# %%
sns.scatterplot(x='MarathonTime', y='km4week', data=df, hue='CATEGORY')
# Out:
# <AxesSubplot:xlabel='MarathonTime', ylabel='km4week'>

# %%
sns.pairplot(df, hue='CATEGORY')

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(df['MarathonTime'], df['km4week'], df['sp4week'], c=df['id'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(df['MarathonTime'], df['km4week'], test_size = 0.30, random_state = 101)

# %%
scaler = StandardScaler()

# %%
#df['MarathonTime'].reshape(-1, 1)
#df['km4week'].reshape(-1, 1)

# %%
#scaled_X_train = scaler.fit_transform(X_train)
#scaled_X_test = scaler.fit_transform(X_test)

#from sklearn.linear_model import LogisticRegression
#log_model = LogisticRegression()

# %%
#log_model.fit(scaled_X_train, y_train)

# %%
#scaled_X_train

# %%
#log_model.coef_

# %%
#from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#y_pred = log_model.predict(scaled_X_test)
#accuracy_score(y_test, y_pred)

# %%
#confusion_matrix(y_test, y_pred)
